# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

sns.set_style("whitegrid")

# %% [markdown]
# # Movie Industry - Is It Worth It?

# %%
movie_budgets = pd.read_csv("data/tn.movie_budgets.csv.gz")
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
# id                   5782 non-null int64
# release_date         5782 non-null object
# movie                5782 non-null object
# production_budget    5782 non-null object
# domestic_gross       5782 non-null object
# worldwide_gross      5782 non-null object
# dtypes: int64(1), object(5)
# memory usage: 271.1+ KB

# %%
movie_budgets[movie_budgets.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, release_date, movie, production_budget, domestic_gross, worldwide_gross]
# Index: []

# %%
def money_str_to_int(ms):
    return int(ms.lstrip("$").replace(",", ""))

# %%
movie_budgets.production_budget = movie_budgets.production_budget.apply(lambda x: money_str_to_int(x))
movie_budgets.domestic_gross = movie_budgets.domestic_gross.apply(lambda x: money_str_to_int(x))
movie_budgets.worldwide_gross = movie_budgets.worldwide_gross.apply(lambda x: money_str_to_int(x))
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
movie_budgets.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross
# count  5782.000000       5.782000e+03    5.782000e+03     5.782000e+03
# mean     50.372363       3.158776e+07    4.187333e+07     9.148746e+07
# std      28.821076       4.181208e+07    6.824060e+07     1.747200e+08
# min       1.000000       1.100000e+03    0.000000e+00     0.000000e+00
# 25%      25.000000       5.000000e+06    1.429534e+06     4.125415e+06
# 50%      50.000000       1.700000e+07    1.722594e+07     2.798445e+07
# 75%      75.000000       4.000000e+07    5.234866e+07     9.764584e+07
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09

# %%
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747

# %%
# Creting some additional columns: Ticket_sales and Profit_margin
movie_budgets['Ticket_sales'] = (movie_budgets.domestic_gross + movie_budgets.worldwide_gross)

# %%
movie_budgets['Profit'] = (movie_budgets.Ticket_sales - movie_budgets.production_budget)

# %%
movie_budgets['Profit_margin'] = (movie_budgets.Profit/movie_budgets.production_budget)

# %%
movie_budgets['Date'] = movie_budgets['release_date'].astype('datetime64[ns]')
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Ticket_sales  \
# 0          425000000       760507625       2776345279    3536852904
# 1          410600000       241063875       1045663875    1286727750
# 2          350000000        42762350        149762350     192524700
# 3          330600000       459005868       1403013963    1862019831
# 4          317000000       620181382       1316721747    1936903129
#
#        Profit  Profit_margin       Date
# 0  3111852904       7.322007 2009-12-18
# 1   876127750       2.133774 2011-05-20
# 2  -157475300      -0.449929 2019-06-07
# 3  1531419831       4.632244 2015-05-01
# 4  1619903129       5.110105 2017-12-15

# %%
#fig = plt.figure(figsize=(20,8))
#plt.scatter(x = movie_budgets.Date, y = movie_budgets.Ticket_sales,)

sns.set(rc={'figure.figsize':(20,8)})
sns.scatterplot(x=movie_budgets.Date, y=movie_budgets.Ticket_sales, hue = movie_budgets['Profit_margin'])
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
movie_budgets["P&L_percent"] = (movie_budgets.domestic_gross + movie_budgets.worldwide_gross - 
                        movie_budgets.production_budget)/movie_budgets.production_budget
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Ticket_sales  \
# 0          425000000       760507625       2776345279    3536852904
# 1          410600000       241063875       1045663875    1286727750
# 2          350000000        42762350        149762350     192524700
# 3          330600000       459005868       1403013963    1862019831
# 4          317000000       620181382       1316721747    1936903129
#
#        Profit  Profit_margin       Date  P&L_percent
# 0  3111852904       7.322007 2009-12-18     7.322007
# 1   876127750       2.133774 2011-05-20     2.133774
# 2  -157475300      -0.449929 2019-06-07    -0.449929
# 3  1531419831       4.632244 2015-05-01     4.632244
# 4  1619903129       5.110105 2017-12-15     5.110105

# %%
movie_budgets["P&L_percent"].hist(bins=100)
plt.show()

# %%
movie_budgets.production_budget.plot.box()
plt.show()

# %%
movie_budgets.loc[movie_budgets.production_budget < 10000].count()
# Out:
# id                   10
# release_date         10
# movie                10
# production_budget    10
# domestic_gross       10
# worldwide_gross      10
# Ticket_sales         10
# Profit               10
# Profit_margin        10
# Date                 10
# P&L_percent          10
# dtype: int64

# %%
movie_budgets.loc[movie_budgets.domestic_gross == 0].count()
# Out:
# id                   548
# release_date         548
# movie                548
# production_budget    548
# domestic_gross       548
# worldwide_gross      548
# Ticket_sales         548
# Profit               548
# Profit_margin        548
# Date                 548
# P&L_percent          548
# dtype: int64

# %%
movie_budgets.loc[movie_budgets.worldwide_gross == 0].count()
# Out:
# id                   367
# release_date         367
# movie                367
# production_budget    367
# domestic_gross       367
# worldwide_gross      367
# Ticket_sales         367
# Profit               367
# Profit_margin        367
# Date                 367
# P&L_percent          367
# dtype: int64

# %%
movie_budgets.loc[movie_budgets.worldwide_gross == movie_budgets.domestic_gross].count()
# Out:
# id                   1619
# release_date         1619
# movie                1619
# production_budget    1619
# domestic_gross       1619
# worldwide_gross      1619
# Ticket_sales         1619
# Profit               1619
# Profit_margin        1619
# Date                 1619
# P&L_percent          1619
# dtype: int64

# %%
movie_budgets.loc[(movie_budgets.domestic_gross == 0) & (movie_budgets.worldwide_gross == 0)].count()
# Out:
# id                   367
# release_date         367
# movie                367
# production_budget    367
# domestic_gross       367
# worldwide_gross      367
# Ticket_sales         367
# Profit               367
# Profit_margin        367
# Date                 367
# P&L_percent          367
# dtype: int64

# %% [markdown]
# Getting rid of 0 domestic **and** 0 worldwide

# %%
movie_budgets = movie_budgets[~((movie_budgets.domestic_gross == 0) & (movie_budgets.worldwide_gross == 0))]
movie_budgets.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5415.000000       5.415000e+03    5.415000e+03     5.415000e+03
# mean     50.227701       3.330801e+07    4.471128e+07     9.768800e+07
# std      28.765167       4.248758e+07    6.960989e+07     1.788591e+08
# min       1.000000       1.100000e+03    0.000000e+00     2.600000e+01
# 25%      25.000000       6.000000e+06    3.160708e+06     7.004834e+06
# 50%      50.000000       1.900000e+07    2.030022e+07     3.333987e+07
# 75%      75.000000       4.200000e+07    5.578249e+07     1.044590e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        Ticket_sales        Profit  Profit_margin  P&L_percent
# count  5.415000e+03  5.415000e+03    5415.000000  5415.000000
# mean   1.423993e+08  1.090913e+08       7.311240     7.311240
# std    2.453305e+08  2.159389e+08      56.714430    56.714430
# min    2.600000e+01 -1.574753e+08      -0.999974    -0.999974
# 25%    1.138616e+07  7.075190e+05       0.142115     0.142115
# 50%    5.420006e+07  3.170742e+07       1.947860     1.947860
# 75%    1.612103e+08  1.217785e+08       5.191397     5.191397
# max    3.536853e+09  3.111853e+09    3599.000000  3599.000000

# %%
movie_budgets["P&L_percent"].plot.hist(bins=500, xlim=(-10,100))

# %%
movie_budgets["P&L_percent"].describe()
# Out:
# count    5415.000000
# mean        7.311240
# std        56.714430
# min        -0.999974
# 25%         0.142115
# 50%         1.947860
# 75%         5.191397
# max      3599.000000
# Name: P&L_percent, dtype: float64

# %%
movie_budgets["P&L_percent"].plot.box()

# %%
movie_budgets[movie_budgets["P&L_percent"]<=0]
# Out:
#        id  release_date                                            movie  \
# 2       3   Jun 7, 2019                                     Dark Phoenix
# 193    94  Mar 11, 2011                                  Mars Needs Moms
# 220    21  Jul 29, 2005                                          Stealth
# 223    24  Jul 11, 2001                Final Fantasy: The Spirits Within
# 254    55  Jul 19, 2013                                         R.I.P.D.
# 280    81  Jan 13, 2017                                   Monster Trucks
# 281    82  Aug 27, 1999                                 The 13th Warrior
# 300     1  Dec 17, 2010                                 How Do You Know?
# 340    41  Jun 16, 2004                      Around the World in 80 Days
# 341    42  Jun 14, 2019                      Men in Black: International
# 352    53  Apr 27, 2001                                   Town & Country
# 402     3  Feb 18, 2005                                  Son of the Mask
# 404     5  Aug 16, 2002                     The Adventures of Pluto Nash
# 405     6  Jan 20, 2012                          Jin lÃ­ng shÃ­ san chai
# 434    35   Apr 9, 2004                                        The Alamo
# 435    36  Dec 22, 1995                                 Cutthroat Island
# 475    76  Aug 19, 2011                              Conan the Barbarian
# 477    78  Apr 21, 2017                                      The Promise
# 478    79  Nov 24, 2010                             The Nutcracker in 3D
# 521    22  Aug 13, 2010                      Scott Pilgrim vs. The World
# 523    24   May 9, 1997                                     Father's Day
# 597    98  May 12, 2000       Battlefield Earth: A Saga of the Year 3000
# 598    99  Nov 14, 2003                     Looney Tunes: Back in Action
# 599   100  Dec 18, 2009                                             Nine
# 600     1  Nov 26, 2003                                         Timeline
# 603     4  Dec 25, 1997                                      The Postman
# 604     5  Nov 10, 2000                                       Red Planet
# 606     7  Aug 17, 2007                                     The Invasion
# 607     8   Sep 2, 2005                               A Sound of Thunder
# 617    18  Dec 31, 2012   AstÃ©rix et ObÃ©lix: Au service de Sa MajestÃ©
# ...   ...           ...                                              ...
# 5632   33  Mar 14, 2014                                         The Word
# 5633   34  Jun 15, 2007                        The Trials of Darryl Hunt
# 5644   45  Feb 27, 2015                                   Butterfly Girl
# 5648   49  Aug 23, 2013                                   Sparrows Dance
# 5651   52  Jun 30, 1979                                          Dolphin
# 5652   53  Dec 31, 2015                                    Lumea e a mea
# 5654   55   Mar 1, 2002                                      The Calling
# 5659   60  Apr 17, 2015                       Antarctic Edge: 70Âº South
# 5660   61  Aug 21, 2015                                         Top Spin
# 5661   62  Dec 31, 2013                                    Speak No Evil
# 5678   79   Oct 3, 2003                           The Work and the Story
# 5744     -19906      -0.737259 2017-01-27    -0.737259
# 5763      -9328      -0.777333 2006-04-28    -0.777333
# 5768      -6026      -0.602600 2004-05-28    -0.602600
# 5769      -8946      -0.894600 1996-04-01    -0.894600
# 5770      -9198      -0.919800 2008-08-14    -0.919800
# 5776      -5200      -0.742857 2004-12-31    -0.742857
# 5779      -2324      -0.464800 2005-07-13    -0.464800
#
# [1241 rows x 11 columns]

# %% [markdown]
# - micro-budget: 0 to 500k [denote 0]
# - low-budget: 500k to 3 mil [denote 1]
# - big-budget: 3 mil to 50 mil [denote 2]
# - mega-budget: anything higher [denote 3]

# %%
def get_budget_cat(pb):
    if pb <= 500000:
        return 0
    elif pb <= 3000000:
        return 1
    elif pb <= 50000000:
        return 2
    else:
        return 3

# %%
movie_budgets["budget_cat"] = movie_budgets.production_budget.apply(lambda x: get_budget_cat(x))
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Ticket_sales  \
# 0          425000000       760507625       2776345279    3536852904
# 1          410600000       241063875       1045663875    1286727750
# 2          350000000        42762350        149762350     192524700
# 3          330600000       459005868       1403013963    1862019831
# 4          317000000       620181382       1316721747    1936903129
#
#        Profit  Profit_margin       Date  P&L_percent  budget_cat
# 0  3111852904       7.322007 2009-12-18     7.322007           3
# 1   876127750       2.133774 2011-05-20     2.133774           3
# 2  -157475300      -0.449929 2019-06-07    -0.449929           3
# 3  1531419831       4.632244 2015-05-01     4.632244           3
# 4  1619903129       5.110105 2017-12-15     5.110105           3

# %%
micro_budget = movie_budgets[movie_budgets.budget_cat == 0]

# %%
low_budget = movie_budgets[movie_budgets.budget_cat == 1]

# %%
big_budget = movie_budgets[movie_budgets.budget_cat == 2]

# %%
mega_budget = movie_budgets[movie_budgets.budget_cat == 3]

# %%
micro_budget["P&L_percent"].hist(bins = 100)

# %%
low_budget["P&L_percent"].hist(bins = 100)

# %%
big_budget["P&L_percent"].hist(bins = 100)

# %%
mega_budget["P&L_percent"].hist(bins = 100)

# %%
micro_budget["P&L_percent"].describe()
# Out:
# count     243.000000
# mean       57.936134
# std       251.527834
# min        -0.997888
# 25%        -0.596230
# 50%         3.385070
# 75%        24.146242
# max      3599.000000
# Name: P&L_percent, dtype: float64

# %%
low_budget["P&L_percent"].describe()
# Out:
# count    626.000000
# mean      12.461433
# std       42.767696
# min       -0.999974
# 25%       -0.645149
# 50%        1.769489
# 75%        9.818285
# max      647.065165
# Name: P&L_percent, dtype: float64

# %%
big_budget["P&L_percent"].describe()
# Out:
# count    3473.000000
# mean        4.179003
# std         8.606183
# min        -0.999769
# 25%         0.016700
# 50%         1.816833
# 75%         5.018284
# max       150.078375
# Name: P&L_percent, dtype: float64

# %%
mega_budget["P&L_percent"].describe()
# Out:
# count    1073.000000
# mean        2.979821
# std         3.042413
# min        -0.992057
# 25%         0.886061
# 50%         2.341332
# 75%         4.179046
# max        21.770173
# Name: P&L_percent, dtype: float64

# %%
fig = plt.figure(figsize=(20,8))

ax1 = fig.add_subplot(141)
micro_budget["P&L_percent"].plot.box()

ax2 = fig.add_subplot(142)
low_budget["P&L_percent"].plot.box()

ax3 = fig.add_subplot(143)
big_budget["P&L_percent"].plot.box()

ax4 = fig.add_subplot(144)
mega_budget["P&L_percent"].plot.box()

# %%
movie_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Ticket_sales  \
# 0          425000000       760507625       2776345279    3536852904
# 1          410600000       241063875       1045663875    1286727750
# 2          350000000        42762350        149762350     192524700
# 3          330600000       459005868       1403013963    1862019831
# 4          317000000       620181382       1316721747    1936903129
#
#        Profit  Profit_margin       Date  P&L_percent  budget_cat
# 0  3111852904       7.322007 2009-12-18     7.322007           3
# 1   876127750       2.133774 2011-05-20     2.133774           3
# 2  -157475300      -0.449929 2019-06-07    -0.449929           3
# 3  1531419831       4.632244 2015-05-01     4.632244           3
# 4  1619903129       5.110105 2017-12-15     5.110105           3

# %%
#now we will do some data cleaning and dropping to get a more useful sample
#first create a copy of budgers
movie_budgets_adj = movie_budgets
movie_budgets_adj.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  5415.000000       5.415000e+03    5.415000e+03     5.415000e+03
# mean     50.227701       3.330801e+07    4.471128e+07     9.768800e+07
# std      28.765167       4.248758e+07    6.960989e+07     1.788591e+08
# min       1.000000       1.100000e+03    0.000000e+00     2.600000e+01
# 25%      25.000000       6.000000e+06    3.160708e+06     7.004834e+06
# 50%      50.000000       1.900000e+07    2.030022e+07     3.333987e+07
# 75%      75.000000       4.200000e+07    5.578249e+07     1.044590e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        Ticket_sales        Profit  Profit_margin  P&L_percent   budget_cat
# count  5.415000e+03  5.415000e+03    5415.000000  5415.000000  5415.000000
# mean   1.423993e+08  1.090913e+08       7.311240     7.311240     1.992798
# std    2.453305e+08  2.159389e+08      56.714430    56.714430     0.702352
# min    2.600000e+01 -1.574753e+08      -0.999974    -0.999974     0.000000
# 25%    1.138616e+07  7.075190e+05       0.142115     0.142115     2.000000
# 50%    5.420006e+07  3.170742e+07       1.947860     1.947860     2.000000
# 75%    1.612103e+08  1.217785e+08       5.191397     5.191397     2.000000
# max    3.536853e+09  3.111853e+09    3599.000000  3599.000000     3.000000

# %%
movie_budgets_adj.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget  domestic_gross  worldwide_gross  Ticket_sales  \
# 0          425000000       760507625       2776345279    3536852904
# 1          410600000       241063875       1045663875    1286727750
# 2          350000000        42762350        149762350     192524700
# 3          330600000       459005868       1403013963    1862019831
# 4          317000000       620181382       1316721747    1936903129
#
#        Profit  Profit_margin       Date  P&L_percent  budget_cat
# 0  3111852904       7.322007 2009-12-18     7.322007           3
# 1   876127750       2.133774 2011-05-20     2.133774           3
# 2  -157475300      -0.449929 2019-06-07    -0.449929           3
# 3  1531419831       4.632244 2015-05-01     4.632244           3
# 4  1619903129       5.110105 2017-12-15     5.110105           3

# %%
#drop movies that have domestic sales == to worldwide sales as we think it is bad user input
movie_budgets_adj = movie_budgets_adj.loc[~(movie_budgets_adj.worldwide_gross == movie_budgets_adj.domestic_gross)]
movie_budgets_adj.Date.count()
# Out:
# 4163

# %%
movie_budgets_adj.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  4163.000000       4.163000e+03    4.163000e+03     4.163000e+03
# mean     49.945232       3.942112e+07    5.348695e+07     1.223961e+08
# std      28.545265       4.603149e+07    7.629709e+07     1.970383e+08
# min       1.000000       6.000000e+03    0.000000e+00     2.600000e+01
# 25%      25.000000       1.000000e+07    5.503604e+06     1.371569e+07
# 50%      50.000000       2.500000e+07    2.832813e+07     5.246054e+07
# 75%      74.000000       5.000000e+07    6.844674e+07     1.469653e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        Ticket_sales        Profit  Profit_margin  P&L_percent   budget_cat
# count  4.163000e+03  4.163000e+03    4163.000000  4163.000000  4163.000000
# mean   1.758831e+08  1.364620e+08       6.872748     6.872748     2.106173
# std    2.699019e+08  2.384882e+08      29.646932    29.646932     0.660383
# min    2.600000e+01 -1.574753e+08      -0.999974    -0.999974     0.000000
# 25%    2.103858e+07  6.092589e+06       0.535785     0.535785     2.000000
# 50%    8.254837e+07  5.162156e+07       2.374278     2.374278     2.000000
# 75%    2.141644e+08  1.631080e+08       5.478041     5.478041     2.000000
# max    3.536853e+09  3.111853e+09     670.337431   670.337431     3.000000

# %%
#drop movies with budgets less than $50K as they too small for our client
movie_budgets_adj = movie_budgets_adj.loc[~(movie_budgets_adj.production_budget < 50000)]
movie_budgets_adj.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  4153.000000       4.153000e+03    4.153000e+03     4.153000e+03
# mean     49.931134       3.951599e+07    5.361418e+07     1.226888e+08
# std      28.563961       4.604621e+07    7.634477e+07     1.971850e+08
# min       1.000000       5.000000e+04    0.000000e+00     2.600000e+01
# 25%      25.000000       1.000000e+07    5.702083e+06     1.391229e+07
# 50%      50.000000       2.500000e+07    2.854416e+07     5.298775e+07
# 75%      74.000000       5.000000e+07    6.854970e+07     1.475424e+08
# max     100.000000       4.250000e+08    9.366622e+08     2.776345e+09
#
#        Ticket_sales        Profit  Profit_margin  P&L_percent   budget_cat
# count  4.153000e+03  4.153000e+03    4153.000000  4153.000000  4153.000000
# mean   1.763030e+08  1.367870e+08       6.609036     6.609036     2.111245
# std    2.700909e+08  2.386831e+08      27.899484    27.899484     0.653029
# min    2.600000e+01 -1.574753e+08      -0.999974    -0.999974     0.000000
# 25%    2.138166e+07  6.281170e+06       0.531185     0.531185     2.000000
# 50%    8.297996e+07  5.190434e+07       2.367173     2.367173     2.000000
# 75%    2.149284e+08  1.636420e+08       5.446686     5.446686     2.000000
# max    3.536853e+09  3.111853e+09     670.337431   670.337431     3.000000

# %%
#drop movies with P&L above 75% (4th Quartile), this will still capture outstanding P&Ls of more than 500% profit
movie_budgets_adj = movie_budgets_adj.loc[~(movie_budgets_adj['P&L_percent'] > 5.5)]

# %%
movie_budgets_adj.describe()
# Out:
#                 id  production_budget  domestic_gross  worldwide_gross  \
# count  3124.000000       3.124000e+03    3.124000e+03     3.124000e+03
# mean     48.701665       4.336108e+07    3.965146e+07     9.271406e+07
# std      28.569648       4.681926e+07    5.416464e+07     1.452669e+08
# min       1.000000       7.000000e+04    0.000000e+00     2.600000e+01
# 25%      24.000000       1.200000e+07    3.128649e+06     1.009028e+07
# 50%      48.000000       2.875000e+07    2.080710e+07     3.917645e+07
# 75%      73.000000       6.000000e+07    5.349547e+07     1.086471e+08
# max     100.000000       4.106000e+08    6.201814e+08     1.403014e+09
#
#        Ticket_sales        Profit  Profit_margin  P&L_percent   budget_cat
# count  3.124000e+03  3.124000e+03    3124.000000  3124.000000  3124.000000
# mean   1.323655e+08  8.900444e+07       1.602651     1.602651     2.184059
# std    1.966651e+08  1.586287e+08       1.778439     1.778439     0.616552
# min    2.600000e+01 -1.574753e+08      -0.999974    -0.999974     0.000000
# 25%    1.494031e+07  7.890105e+05       0.134233     0.134233     2.000000
# 50%    6.080716e+07  3.042086e+07       1.375837     1.375837     2.000000
# 75%    1.633242e+08  1.090088e+08       2.973619     2.973619     3.000000
# max    1.936903e+09  1.619903e+09       5.495607     5.495607     3.000000

# %%
#movies with negative P&Ls
movie_budgets_adj['P&L_percent'].loc[(movie_budgets_adj['P&L_percent']<0)].count()
# Out:
# 717

# %%
sns.set(rc={'figure.figsize':(20,10)})
plt.title('Historical Ticket_sales by Production Budget, ($USD, billons)', fontsize = 14)
sns.scatterplot(x=movie_budgets_adj.Date.tolist(), y=(movie_budgets_adj['Ticket_sales']), 
                hue = movie_budgets_adj['budget_cat'], size = ((movie_budgets_adj['Profit_margin'])))
#Date goes back to 1936, technology and dollar value were very different, thus drop all till the '90s
plt.xlim(datetime(1940, 1, 1), datetime(2020, 1, 1))
plt.ylim(0.00, None)
# Out:
# (0.0, 2033748284.1509027)

# %%
sns.distplot(movie_budgets_adj['Profit'], bins = 100),
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1a26d04d68>,)

# %%
sns.jointplot(x=movie_budgets_adj['domestic_gross'], y=movie_budgets_adj['worldwide_gross'], kind='scatter', space = 0.0001, )

# %%
plt.scatter(x =movie_budgets_adj.Date, y=movie_budgets_adj.Ticket_sales)

# %%
plt.figure(figsize = (20,8))
plt.title('Histogram of Profit and Loss (P&L) as % of Production Budget', fontsize = 14)
data = movie_budgets_adj['P&L_percent']
plt.hist(x = data, bins = 100, range = (-1, 6))
# to do: show 717 titles with P&L <0 in red color, also convert x-axis in % from -100% to 550%
plt.show()

# %%
micro_budget_adj = movie_budgets_adj[movie_budgets_adj.budget_cat == 0]
low_budget_adj = movie_budgets_adj[movie_budgets_adj.budget_cat == 1]
big_budget_adj = movie_budgets_adj[movie_budgets_adj.budget_cat == 2]
mega_budget_adj = movie_budgets_adj[movie_budgets_adj.budget_cat == 3]

# %%
fig = plt.figure(figsize=(20,8))

ax1 = fig.add_subplot(141)
micro_budget_adj["P&L_percent"].plot.box()

ax2 = fig.add_subplot(142)
low_budget_adj["P&L_percent"].plot.box()

ax3 = fig.add_subplot(143)
big_budget_adj["P&L_percent"].plot.box()

ax4 = fig.add_subplot(144)
mega_budget_adj["P&L_percent"].plot.box()

plt.show()

# Based on our findings below (see 4 boxplot charts) it is our recommendation to avoid micro-budget (<=$.5M) and 
# low badget (<=$3M) strategies as these movies tend to have larger volatility of ticket sales and may lose money. 
# Big-budget (<=$50M) and mega-budget strategies seem to be warranted from expected profitability stand point of view.

# %%
fig = plt.figure(figsize=(20,8))

ax1 = fig.add_subplot(141)
micro_budget["P&L_percent"].plot.box()

ax2 = fig.add_subplot(142)
low_budget["P&L_percent"].plot.box()

ax3 = fig.add_subplot(143)
big_budget["P&L_percent"].plot.box()

ax4 = fig.add_subplot(144)
mega_budget["P&L_percent"].plot.box()

plt.show()
